# %% [markdown]
# # Task 1 #

# %% [markdown]
# ### a. Movis longer than 3h (180 minutes) ###

# %%
# with duck db
film_length = duckdb.sql("""
    SELECT
        title,
        length
    FROM
        film
    WHERE
        length > 180
""").df()

film_length
# Out:
#                  title  length
# 0     ANALYZE HOOSIERS     181
# 1      BAKED CLEOPATRA     182
# 2        CATCH AMISTAD     183
# 3        CHICAGO NORTH     185
# 4    CONSPIRACY SPIRIT     184
# 5       CONTROL ANTHEM     185
# 6     CRYSTAL BREAKING     184
# 7       DARN FORRESTER     185
# 8       FRONTIER CABIN     183
# 9          GANGS PRIDE     185
# 10    HAUNTING PIANIST     181
# 11           HOME PITY     185
# 12     HOTEL HAPPINESS     181
# 13      INTRIGUE WORST     181
# 14       JACKET FRISCO     181
# 15      KING EVOLUTION     184
# 16      LAWLESS VISION     181
# 17       LOVE SUICIDES     181
# 18       MONSOON CAUSE     182
# 19     MOONWALKER FOOL     184
# 20       MUSCLE BRIGHT     185
# 21        POND SEATTLE     185
# 22       RECORDS ZORRO     182
# 23          REDS POCUS     182
# 24  RUNAWAY TENENBAUMS     181
# 25         SATURN NAME     182
# 26       SCALAWAG DUCK     183
# 27      SEARCHERS WAIT     182
# 28     SMOOCHY CONTROL     184
# 29  SOLDIERS EVOLUTION     185
# 30      SONS INTERVIEW     184
# 31      SORORITY QUEEN     184
# 32      STAR OPERATION     181
# 33   SWEET BROTHERHOOD     185
# 34      THEORY MERMAID     184
# 35           WIFE TURN     183
# 36         WILD APOLLO     181
# 37        WORST BANGER     185
# 38      YOUNG LANGUAGE     183

# %% [markdown]
# ### b. Movies with the word 'love' in the title ###

# %%
film_love_title = duckdb.sql("""
    SELECT
        title,
        rating,
        length,
        description
    FROM
        film
    WHERE
        title LIKE '%LOVE%'
""").df()

film_love_title
# Out:
#                 title rating  length  \
# 0       GRAFFITI LOVE     PG     117
# 1          IDAHO LOVE  PG-13     172
# 2      IDENTITY LOVER  PG-13     119
# 3         INDIAN LOVE  NC-17     135
# 4       LAWRENCE LOVE  NC-17     175
# 5       LOVE SUICIDES      R     181
# 6       LOVELY JINGLE     PG      65
# 7        LOVER TRUMAN      G      75
# 8    LOVERBOY ATTACKS  PG-13     162
# 9  STRANGELOVE DESIRE  NC-17     103
#
#                                          description
# 0  A Unbelieveable Epistle of a Sumo Wrestler And...
# 1  A Fast-Paced Drama of a Student And a Crocodil...
# 2  A Boring Tale of a Composer And a Mad Cow who ...
# 3  A Insightful Saga of a Mad Scientist And a Mad...
# 4  A Fanciful Yarn of a Database Administrator An...
# 5  A Brilliant Panorama of a Hunter And a Explore...
# 6  A Fanciful Yarn of a Crocodile And a Forensic ...
# 7  A Emotional Yarn of a Robot And a Boy who must...
# 8  A Boring Story of a Car And a Butler who must ...
# 9  A Awe-Inspiring Panorama of a Lumberjack And a...

# %% [markdown]
# ### c. Statistiscs: Film lengths

# %%
length_statistics = duckdb.sql("""
SELECT
    MIN(length) AS shortest_length,
    MAX(length) AS longest_length,
    ROUND(AVG(length)) AS average_length,
    ROUND(MEDIAN(length)) AS median_length
    FROM
        film
""").df()

length_statistics
# Out:
#    shortest_length  longest_length  average_length  median_length
# 0               46             185           115.0          114.0

# %% [markdown]
# ### d. Rental cost: Top 10 most expensive movies (price per day) ###

# %%
rent_price = duckdb.sql("""
SELECT
    title,
    ROUND(rental_rate / rental_duration) AS daily_rental_cost
    FROM
        film
    ORDER BY daily_rental_cost DESC
    LIMIT 10
""").df()

rent_price
# Out:
#                  title  daily_rental_cost
# 0       ACE GOLDFINGER                2.0
# 1          AUTUMN CROW                2.0
# 2     BEHAVIOR RUNAWAY                2.0
# 3      BEAST HUNCHBACK                2.0
# 4  BACKLASH UNDEFEATED                2.0
# 5    CARIBBEAN LIBERTY                2.0
# 6      BILKO ANONYMOUS                2.0
# 7     CASPER DRAGONFLY                2.0
# 8      AMERICAN CIRCUS                2.0
# 9    CASUALTIES ENCINO                2.0

# %% [markdown]
# ### e. Top 10 actors - based on number of movies

# %%
with duckdb.connect("data/sakila.duckdb") as conn:
    top_actors = conn.sql("""
        SELECT
            a.first_name,
            a.last_name,
            COUNT(fa.film_id) AS nr_films
        FROM
            actor a
        LEFT JOIN staging.film_actor fa ON a.actor_id = fa.actor_id
        GROUP BY a.actor_id, a.first_name, a.last_name
        ORDER BY nr_films DESC
        LIMIT 10                            
    """).df()

top_actors
# Out:
#   first_name    last_name  nr_films
# 0       GINA    DEGENERES        42
# 1     WALTER         TORN        41
# 2       MARY       KEITEL        40
# 3    MATTHEW       CARREY        39
# 4     SANDRA       KILMER        37
# 5   SCARLETT        DAMON        36
# 6     VIVIEN     BASINGER        35
# 7        VAL       BOLGER        35
# 8     ANGELA  WITHERSPOON        35
# 9        UMA         WOOD        35

# %% [markdown]
# ### f. Statistics: Rental length

# %%
dfs["film"]["rental_duration"].describe().round(0)
# Out:
# count    1000.0
# mean        5.0
# std         1.0
# min         3.0
# 25%         4.0
# 50%         5.0
# 75%         6.0
# max         7.0
# Name: rental_duration, dtype: float64

# %% [markdown]
# ### g. Most rented movies

# %%
with duckdb.connect("data/sakila.duckdb") as conn:
    top_movies = conn.sql("""
        SELECT
            title,
            rating,
            release_year,
            COUNT(*) AS nr_rentals
        FROM
            staging.rental r
        JOIN staging.inventory i ON r.inventory_id = i.inventory_id
        JOIN staging.film f ON i.film_id = f.film_id
        GROUP BY f.film_id, f.title, f.rating, f.release_year
        ORDER BY nr_rentals DESC
        LIMIT 10                            
    """).df()

top_movies
# Out:
#                  title rating release_year  nr_rentals
# 0   BUCKET BROTHERHOOD     PG         2006          34
# 1     ROCKETEER MOTHER  PG-13         2006          33
# 2       GRIT CLOCKWORK     PG         2006          32
# 3       JUGGLER HARDLY  PG-13         2006          32
# 4  RIDGEMONT SUBMARINE  PG-13         2006          32
# 5        SCALAWAG DUCK  NC-17         2006          32
# 6       FORWARD TEMPLE  NC-17         2006          32
# 7            ZORRO ARK  NC-17         2006          31
# 8      RUSH GOODFELLAS     PG         2006          31
# 9         ROBBERS JOON  PG-13         2006          31

# %% [markdown]
# ### h. How many languages does our system support and how many different languages of movies exist right now in our system

# %%
dfs["language"]["name"].value_counts()
# Out:
# name
# English     1
# Italian     1
# Japanese    1
# Mandarin    1
# French      1
# German      1
# Name: count, dtype: int64

# %%
movie_languages = dfs["language"].merge(dfs["film"], on="language_id")

films_per_language = movie_languages["name"].value_counts()

films_per_language
# Out:
# name
# English    1000
# Name: count, dtype: int64
